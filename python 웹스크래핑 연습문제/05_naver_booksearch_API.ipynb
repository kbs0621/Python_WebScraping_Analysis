# %%
import os
import requests
import json
import pandas as pd

client_id = "ochSGjtA3spwAXkGXiEZ"  # 여기에 본인 클라이언트 ID
client_secret = "GDo3VL_YBL"  # 여기에 본인 클라이언트 Secret

# 공통 headers
def get_headers():
    return {
        'X-Naver-Client-Id': client_id,
        'X-Naver-Client-Secret': client_secret
    }

# 책 검색 함수
def search_books(query):
    url = "https://openapi.naver.com/v1/search/book.json"
    payload = {
        'query': query,
        'display': 50,
        'sort': 'sim'
    }

    res = requests.get(url, params=payload, headers=get_headers())

    if res.ok:
        return res.json().get('items', [])
    else:
        print(f"API 요청 실패: {res.status_code}")
        return []

# Json 저장 함수
def save_to_json(data, filepath):
    os.makedirs(os.path.dirname(filepath), exist_ok=True)
    with open(filepath, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=4)

# Json → DataFrame
def json_to_dataframe(filepath):
    with open(filepath, 'r', encoding='utf-8') as f:
        data = json.load(f)
    df = pd.DataFrame(data)
    
    for col in ['discount', 'pubdate']:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)
    return df

# 책 목록 출력
def print_book(books_df):
    for idx, (row) in enumerate(books_df.iterrows(), 1):
        print(f"{idx}. 제목 : {row['title']}")
        print(f"    저자: {row['author']}")
        print(f"    출판사: {row['publisher']}")
        print(f"    출간일: {row['pubdate']}")
        print(f"    링크: {row['link']}")
        print("=" * 50)

# %%
#질문 : 검색어로 찾은 책 목록을 json 파일로 저장하기
query = input("검색할 책 제목을 입력하세요: ")
books = search_books(query)

if books:
    save_to_json(books, 'data/books.json')
    print(f"{query} 책이 books.json파일로 저장되었습니다.")
else:
    print("검색 결과가 없습니다.")
# Out:
# <class 'list'>
# python 책이 books.json파일로 저장되었습니다.

# %%
# books.json 파일을 Pandas DataFrame으로 저장하기
df = json_to_dataframe('data/books.json')
print("books.json 파일이 DataFrame으로 저장되었습니다.")
# Out:
# books.json 파일이 DataFrame으로 저장되었습니다.

# %%
# 검색어로 찾은 책 목록 출력하기
df
# Out:
#                                                 title  \
# 0   2025 이기적 빅데이터분석기사 실기 Python (개념과 기출로 실전에 강한 완벽...
# 1              Python (A Practical Learning Approach)
# 2              Python (A Practical Learning Approach)
# 3                Python (Python basics for Beginners)
# 4   Python (This book includes : Python basics for...
# 5   Python (2 Books in 1. Python For Beginners, Ma...
# 6   PYTHON (The Complete Crash Course to Learn Pyt...
# 7   PYTHON (The Complete Crash Course to Learn Pyt...
# 8                                              Python
# 9                                              Python
# 10  Python (Learn Python Programming in One Week w...
# 11                       Python (머리에 쏙쏙 들어오는 파이썬 안내서)
# 12                   Python (Visual QuickStart Guide)
# 13            Python (The Road to Driving Confidence)
# 14   Legendary Leitrim - exploring north west Ireland
# 15                               코딩입문 PYTHON (미래를 듣다)
# 16  Stone Age Farming  3rd edition (-Tapping into ...
# 17                                        Python 리터러시
# 18             알고리즘으로 배우는 수치해석: Python 활용 (Python 활용)
# 19  Python and SQL (Laying the Foundations for Fut...
# 20                                         Python 101
# 21                                  R과 Python 활용 통계분석
# 22     데이터과학을 위한 확률.통계: R과 Python의 활용 (R과 Python의 활용)
# 23         파이썬Python과 언어 연구 (중국어와 일본어 연구자를 위한 실용 안내서)
# 24      처음 만나는 통계와 데이터분석: R과 Python 활용 (R과 Python 활용)
# 25                   파이썬(Python) 3 (쉽고 재미있는 프로그래밍 언어)
# 26                             The Python (파이썬 프로그래밍)
# 27                      비트코딩 Python (최초의 문제은행식 코딩문제집)
# 28                                         Pro Python
# 29                                         Pro Python
# 30  Unlocking Python (A Comprehensive Guide for Be...
# 31  Foundations of Statistics for Data Scientists ...
# 32                                R과 Python 활용 계량경제분석
# 33           데이터 과학 입문: R과 Python의 활용 (R과 Python의 활용)
# 34                      Python 프로그래밍 (스마트로봇 EV3를 활용한)
# 35  Applied Scientific Computing 양장본 Hardcover (Wi...
# 36         Applied Scientific Computing (With Python)
# 37                                       Python 프로그래밍
# 38     데이터과학자를 위한 통계분석 STATA  Python (STATA & Python)
# 39  Python Programming (Machine Learning & Data Sc...
# 40  Python Programming (Machine Learning & Data Sc...
# 41                                  PYTHON으로 배우는 자료구조
# 42                         기초통계플러스알파 (R과 Python을 활용한)
# 43  처음 만나는 통계와 데이터분석: R과 Python 활용 (R과 Python 활용, ...
# 44       Peasant in Paradise: four seasons eco-living
# 45  Learn Python (Get Started Now with Our Beginne...
# 46  Learn Python (Get Started Now with Our Beginne...
# 47  Learn Python (Get Started Now with Our Beginne...
# 48  Learn Python (Get Started Now with Our Beginne...
# 49   파이썬(Python): 1학년 (파이썬, 만화와 대화로 공부해 인공지능 앱까지 도전!)
#
#                                                  link  \
# 0   https://search.shopping.naver.com/book/catalog...
# 1   https://search.shopping.naver.com/book/catalog...
# 2   https://search.shopping.naver.com/book/catalog...
# 3   https://search.shopping.naver.com/book/catalog...
# 4   https://search.shopping.naver.com/book/catalog...
# 5   https://search.shopping.naver.com/book/catalog...
# 6   https://search.shopping.naver.com/book/catalog...
# 7   https://search.shopping.naver.com/book/catalog...
# 8   https://search.shopping.naver.com/book/catalog...
# 9   https://search.shopping.naver.com/book/catalog...
# 10  https://search.shopping.naver.com/book/catalog...
# 11  https://search.shopping.naver.com/book/catalog...
# 12  https://search.shopping.naver.com/book/catalog...
# 13  https://search.shopping.naver.com/book/catalog...
# 14  https://search.shopping.naver.com/book/catalog...
# 15  https://search.shopping.naver.com/book/catalog...
# 16  https://search.shopping.naver.com/book/catalog...
# 17  https://search.shopping.naver.com/book/catalog...
# 18  https://search.shopping.naver.com/book/catalog...
# 19  https://search.shopping.naver.com/book/catalog...
# 20  https://search.shopping.naver.com/book/catalog...
# 21  https://search.shopping.naver.com/book/catalog...
# 22  https://search.shopping.naver.com/book/catalog...
# 23  https://search.shopping.naver.com/book/catalog...
# 24  https://search.shopping.naver.com/book/catalog...
# 25  https://search.shopping.naver.com/book/catalog...
# 26  https://search.shopping.naver.com/book/catalog...
# 27  https://search.shopping.naver.com/book/catalog...
# 28  https://search.shopping.naver.com/book/catalog...
# 29  https://search.shopping.naver.com/book/catalog...
# 30  https://search.shopping.naver.com/book/catalog...
# 31  https://search.shopping.naver.com/book/catalog...
# 32  https://search.shopping.naver.com/book/catalog...
# 33  https://search.shopping.naver.com/book/catalog...
# 34  https://search.shopping.naver.com/book/catalog...
# 35  https://search.shopping.naver.com/book/catalog...
# 36  https://search.shopping.naver.com/book/catalog...
# 37  https://search.shopping.naver.com/book/catalog...
# 38  https://search.shopping.naver.com/book/catalog...
# 39  https://search.shopping.naver.com/book/catalog...
# 40  https://search.shopping.naver.com/book/catalog...
# 41  https://search.shopping.naver.com/book/catalog...
# 42  https://search.shopping.naver.com/book/catalog...
# 43  https://search.shopping.naver.com/book/catalog...
# 44  https://search.shopping.naver.com/book/catalog...
# 45  https://search.shopping.naver.com/book/catalog...
# 46  https://search.shopping.naver.com/book/catalog...
# 47  https://search.shopping.naver.com/book/catalog...
# 48  https://search.shopping.naver.com/book/catalog...
# 49  https://search.shopping.naver.com/book/catalog...
#
#                                                 image  \
# 0   https://shopping-phinf.pstatic.net/main_536248...
# 1   https://shopping-phinf.pstatic.net/main_492487...
# 2   https://shopping-phinf.pstatic.net/main_492487...
# 3   https://shopping-phinf.pstatic.net/main_324603...
# 4   https://shopping-phinf.pstatic.net/main_324449...
# 5   https://shopping-phinf.pstatic.net/main_514474...
# 6   https://shopping-phinf.pstatic.net/main_514460...
# 7   https://shopping-phinf.pstatic.net/main_514466...
# 8   https://shopping-phinf.pstatic.net/main_514477...
# 9   https://shopping-phinf.pstatic.net/main_325494...
# 10  https://shopping-phinf.pstatic.net/main_514474...
# 11  https://shopping-phinf.pstatic.net/main_324933...
# 12  https://shopping-phinf.pstatic.net/main_325225...
# 13  https://shopping-phinf.pstatic.net/main_514460...
# 14  https://shopping-phinf.pstatic.net/main_558027...
# 15  https://shopping-phinf.pstatic.net/main_538281...
# 16  https://shopping-phinf.pstatic.net/main_550981...
# 17  https://shopping-phinf.pstatic.net/main_525205...
# 18  https://shopping-phinf.pstatic.net/main_345129...
# 19  https://shopping-phinf.pstatic.net/main_550329...
# 20  https://shopping-phinf.pstatic.net/main_514465...
# 21  https://shopping-phinf.pstatic.net/main_544706...
# 22  https://shopping-phinf.pstatic.net/main_498159...
# 23  https://shopping-phinf.pstatic.net/main_543692...
# 24  https://shopping-phinf.pstatic.net/main_324877...
# 25  https://shopping-phinf.pstatic.net/main_324416...
# 26  https://shopping-phinf.pstatic.net/main_324670...
# 27  https://shopping-phinf.pstatic.net/main_324833...
# 28  https://shopping-phinf.pstatic.net/main_324440...
# 29  https://shopping-phinf.pstatic.net/main_324568...
# 30  https://shopping-phinf.pstatic.net/main_548965...
# 31  https://shopping-phinf.pstatic.net/main_549543...
# 32  https://shopping-phinf.pstatic.net/main_541164...
# 33  https://shopping-phinf.pstatic.net/main_324622...
# 34  https://shopping-phinf.pstatic.net/main_324902...
# 35  https://shopping-phinf.pstatic.net/main_353017...
# 36  https://shopping-phinf.pstatic.net/main_473427...
# 37  https://shopping-phinf.pstatic.net/main_338121...
# 38  https://shopping-phinf.pstatic.net/main_510930...
# 39  https://shopping-phinf.pstatic.net/main_547698...
# 40  https://shopping-phinf.pstatic.net/main_547245...
# 41  https://shopping-phinf.pstatic.net/main_518854...
# 42  https://shopping-phinf.pstatic.net/main_381774...
# 43  https://shopping-phinf.pstatic.net/main_467893...
# 44  https://shopping-phinf.pstatic.net/main_331375...
# 45  https://shopping-phinf.pstatic.net/main_325387...
# 46  https://shopping-phinf.pstatic.net/main_325337...
# 47  https://shopping-phinf.pstatic.net/main_324665...
# 48  https://shopping-phinf.pstatic.net/main_324923...
# 49  https://shopping-phinf.pstatic.net/main_324640...
#
#                                                author  discount  \
# 0                                              이삭^김상돈     27360
# 1                                                        253800
# 2                                                        101490
# 3                                                         43420
# 4                                                        104230
# 5                                                             0
# 6                                                             0
# 7                                                             0
# 8                                                             0
# 9                                                         50370
# 10                                                            0
# 11                                               폴 배리         0
# 12                                                        31320
# 13                                                            0
# 14                                                        52100
# 15                                                김강현     26600
# 16                                                        52120
# 17                                                민상준     19200
# 18                                                최덕기     28500
# 19                                                        52100
# 20                                                            0
# 21                                                강기춘     34200
# 22                                                허명회     22800
# 23                                                리원핑     23400
# 24                                                윤정연         0
# 25                                                 최용     22500
# 26                                                허진경         0
# 27                                                박해민         0
# 28                                       Marty Alchin     86850
# 29                                                        78160
# 30                                                        71230
# 31                                                            0
# 32                                                강기춘     37620
# 33                                                허명회     19000
# 34                                        남상엽^김상범^강현웅     27600
# 35  Peter R. Turner^Thomas Arildsen^Kathleen Kavanagh     95540
# 36                                                        69480
# 37                                                서문석     11500
# 38                                            민인식^최필선     30400
# 39                                                        86850
# 40                                                       173730
# 41                         홍지만^한정규^민홍^정진만^이재흥^장준혁^허준영     26600
# 42                                        김명준^김영화^박영호     28500
# 43                                                윤정연     18900
# 44                                                        60810
# 45                                                        61630
# 46                                     Adams, Anthony     50070
# 47                                                        67370
# 48                                                        48100
# 49                                            모리 요시나오         0
#
#                         publisher   pubdate           isbn  \
# 0                            영진닷컴  20250411  9788931477191
# 1                       CRC Press  20240807  9781032712642
# 2                       CRC Press  20240807  9781032712666
# 3            Ladoo Publishing LLC  20210801  9781955786331
# 4            Ladoo Publishing LLC  20210730  9781955786324
# 5   Smart Digital Performance Ltd  20210412  9781802347975
# 6                   diomede ienna  20210321  9781801548366
# 7                   diomede ienna  20210317  9781801548458
# 8                    Mikcorp Ltd.  20201228  9781801571296
# 9               Davide Cicatiello  20201102  9781801157032
# 10                     Dia Thabet  20200508  9798644385539
# 11                          한빛미디어  20111028  9788979148688
# 12                 Peachpit Press  20011001  9780201748840
# 13                 Caboodle Books  20111001  9780956948205
# 14                   Python Press  20250724  9780645285475
# 15                          복두출판사  20250325  9791166756030
# 16                   Python Press  20250601  9780645285451
# 17                     부크크(bookk)  20241230  9791141970338
# 18                          학산미디어  20220915  9791185294377
# 19            Charles M Dominquez  20250526  9781806254019
# 20               Michael Driscoll  20140603  9780996062817
# 21                            한경사  20250428  9788968445347
# 22                         자유아카데미  20240820  9791158086305
# 23                             역락  20250312  9791167428950
# 24                        한국금융연수원  20220314  9788928726943
# 25                         인피니티북스  20140212  9791185578002
# 26                     부크크(Bookk)  20181113  9791127251765
# 27                       햄큐(HAMQ)  20181019  9791196328832
# 28                         Apress  20100601  9781430227571
# 29                         Apress  20150107  9781484203354
# 30                          Wiley  20250513  9781394288496
# 31                                 20250523  9780367748432
# 32                            한경사  20250410  9788968445330
# 33                         자유아카데미  20210925  9791158083229
# 34                            상학당  20200915  9788965872023
# 35                       Springer  20180731  9783319895741
# 36           Springer Nature B.V.  20180723  9783319895765
# 37                             퍼플  20170330  9788924046915
# 38                          지필미디어  20241030  9791193187623
# 39                             e3  20250510  9798231693771
# 40                             e3  20250509  9798231631063
# 41                             홍릉  20241130  9791156002321
# 42                            경문사  20230302  9791160736090
# 43                        한국금융연수원  20240401  9788928781959
# 44                   Python Press  20210915  9780645285406
# 45                   Big Book Ltd  20210226  9781914065606
# 46                   Big Book Ltd  20210210  9781914065590
# 47                   Big Book Ltd  20201224  9781914065316
# 48                   Big Book Ltd  20201209  9781914065088
# 49                            성안당  20181218  9788931555684
#
#                                           description
# 0   여러분의 데이터 분석 공부를 재미있게!\n\n유튜브 누적 130만 view의 슬기로...
# 1   The book, "Python - A Practical Learning Appro...
# 2   The book, "Python - A Practical Learning Appro...
# 3   Are you thinking about learning how to use the...
# 4   Are you thinking about learning how to use the...
# 5   ★ ★ ★ 55% OFF for Bookstores! ★ ?★ ★Do you wan...
# 6   Do you know what Python is?Python programming ...
# 7   Do you know what Python is?Python programming ...
# 8   Includes 3 manuscriptsLearn Python Programming...
# 9   DescriptionAre you one of those individuals wh...
# 10  Have you always wanted to learn computer progr...
# 11  고유한 기법으로 파이썬 언어를 가르치는 실용 안내서 『헤드 퍼스트 파이썬』. 파이썬...
# 12  The quick and easy way to master Python for In...
# 13  Age range 6 to 9Daniel is scared of two things...
# 14  Time travel through serene green, hidden-treas...
# 15  김강현의 『코딩입문 PYTHON』은 〈파이썬 개요1.1 파이썬 소개〉, 〈파이썬을 ...
# 16  Full of unusual, esoteric tips for food growin...
# 17  "Python 리터러시"는 파이썬 입문서와 함께 공부하는 파이썬 연습문제입니다.\n...
# 18  이 책은 수치해석에 대한 최신의 경향을 따라가기 위해서, 수학적 배경, 알고리즘, ...
# 19  Curious how today's tech giants make data-driv...
# 20  Learn how to program with Python 3 from beginn...
# 21
# 22  수학과 컴퓨팅이 데이터 과학에서 중요한 두 요소라는 것이 저자의 소신이다. 그렇지만...
# 23  이 책은 중국어와 일본어 연구자를 위한 Python 입문서이다.\n언어 연구에서 컴...
# 24  통계와 데이터분석은 금융권 업무와 동떨어져 있고, 극소수의 사람만 알면 되는 그다지...
# 25  『파이썬(Python) 3』은 쉽고 강력한 프로그래밍 언어인 파이썬에 대한 책이다....
# 26  파이썬을 배우기 위해 여러권의 책이 필요 없습니다. 파이썬에 관한 단 한권의 책을 ...
# 27  『비트코딩 Python』은 문제은행식 코딩 문제집으로 총 516문항을 수록하였다. ...
# 28  Not only will this book help your code, it wil...
# 29  Pro Python, Second Edition explores concepts a...
# 30  A fun and practical guide to learning Python w...
# 31  This book shows the elements of statistical sc...
# 32
# 33  이 책은 성신여자대학교에서 “빅데이터의 이해와 활용”을 가르치면서 쓴 강의 텍스트 ...
# 34  『Python 프로그래밍』은 〈스마트로봇 EV3의 개요 및 구성〉, 〈파이썬의 개요...
# 35  This easy-to-understand textbook presents a mo...
# 36  This easy-to-understand textbook presents a mo...
# 37  4차 산업 혁명 시대의 중심에 서 있는 현대인들에게 프로그래밍 언어를 배워 프로그램...
# 38  AI와 데이터 과학의 시대가 도래하면서 방대한 데이터 속에서 의미 있는 통찰을 도출...
# 39  PrefaceIn recent years, Machine Learning and D...
# 40  Book DescriptionThe explosive growth of data i...
# 41                               알고리즘 공부를 위한 실전적 자료구조
# 42  데이터가 있는 곳에 통계가 있다!\n\n빅데이터의 활용으로 4차 산업혁명 시대인 현...
# 43  통계와 데이터분석은 금융권 업무와 동떨어져 있고, 극소수의 사람만 알면 되는 그다지...
# 44  A down-to-earth and fun look at saving the pla...
# 45  Do you want to become a coding & programming e...
# 46  Do you want to become a coding & programming e...
# 47  Do you want to become a coding & programming e...
# 48  Do you want to become a coding & programming e...
# 49  만화처럼 빨려 들어가는 비주얼한 프로그래밍 입문서 1학년 시리즈! \n염소 박사님,...

# %%
# 질문 : 검색어로 찾은 책 목록 중에서 특정 가격인 책만 출력하기 
# title,author,discount, publisher, pubdate 칼럼만 출력
# 가격별 내림차순으로 정렬, index 초기화
df.loc[df['discount'] > 20000, ['title','author','discount','publisher','pubdate']]\
.sort_values(by='discount', ascending=False).reset_index(drop=True)

# %%
# 질문 : 검색어로 찾은 책 목록 중에서 특정 출판사인 책만 출력하기
# image, description 칼럼을 제외한 모든 칼럼 출력하기, index는 초기화
df.loc[df['publisher'] == '인피니티북스', df.columns.drop(['image','description'])]\
.reset_index(drop=True)
# Out:
#                               title  \
# 0  파이썬(Python) 3 (쉽고 재미있는 프로그래밍 언어)
#
#                                                 link author  discount  \
# 0  https://search.shopping.naver.com/book/catalog...     최용     22500
#
#   publisher   pubdate           isbn
# 0    인피니티북스  20140212  9791185578002
